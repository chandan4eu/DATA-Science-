# %% [markdown]
# # flask

# %% [markdown]
# ## 1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
#  <p>flask is a web application framework written in python.
#  its is easy to use.
#  purely based on python
#
# Size is everything, and Flask’s status as a microframework means that you can use it to grow a tech project such as a web app incredibly quickly. If you want to make an app that starts small, but has the potential to grow quickly and in directions you haven’t completely worked out yet, then it’s an ideal choice. Its simplicity of use and few dependencies enable it to run smoothly even as it scales up and up.<p>

# %% [markdown]
# ## Create a simple Flask application to display ‘Hello World!!’.

# %%
# importing Flask from flask
from flask import Flask

# %%
#app = Flask(__name__)

# %%
'''
@app.route("/")
def hellow():
    return "Hello"
    '''
# Out:
# '\n@app.route("/")\ndef hellow():\n    return "Hello"\n    '

# %%
#app.run()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img=cv2.imread('flask1.jpeg')

# %%
plt.imshow(img)
plt.title("screenshot")
plt.show()

# %% [markdown]
# ## What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# <p> app routing means binding a url to function. we use app routes to make the function accessible globally (language independently)<p>

# %% [markdown]
# <h3> Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999</h3>

# %%
#app = Flask(__name__)

# %%
''' @app.route("/welcomee")
def welcomee():
    return "Welcome to ABC Corporation"
@app.route("/")
def detailss():
   return "<ul type : none> <li>Company Name: ABC Corporation </li><li> Location: India </li><li>Contact Detail: 999-999-9999</ul </li> "
    


    '''
# Out:
# ' @app.route("/welcomee")\ndef welcomee():\n    return "Welcome to ABC Corporation"\n@app.route("/")\ndef detailss():\n   return "<ul type : none> <li>Company Name: ABC Corporation </li><li> Location: India </li><li>Contact Detail: 999-999-9999</ul </li> "\n    \n\n\n    '

# %%
#app.run()

# %%
img2= cv2.imread("flask2.jpeg")

# %%
img3=cv2.imread("flask3.jpeg")

# %%
plt.imshow(img2)
plt.title("screenshot")
plt.show()

# %%
plt.imshow(img3)
plt.title("screenshot")
plt.show()

# %% [markdown]
# ## What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# The url_for() function is very useful for dynamically building a URL for a specific function. The function accepts the name of a function as first argument, and one or more keyword arguments, each corresponding to the variable part of URL.

# %%
from flask import redirect , url_for
app = Flask(__name__)

@app.route('/admin')
def hello_admin():
   return 'Hello Admin'

@app.route('/guest/<guest>')
# guest is p
def hello_guest(guest):
   return 'Hello %s as Guest' % guest

@app.route('/user/<name>')
def hello_user(name):
   if name =='admin':
      return redirect(url_for('hello_admin'))
   else:
      return redirect(url_for('hello_guest',guest = name))
app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [27/Feb/2023 11:20:50] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [27/Feb/2023 11:20:56] "GET /admim HTTP/1.1" 404 -
# 127.0.0.1 - - [27/Feb/2023 11:21:00] "GET /admin HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Feb/2023 11:21:10] "GET /user/chandan HTTP/1.1" 302 -
# 127.0.0.1 - - [27/Feb/2023 11:21:10] "GET /guest/chandan HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Feb/2023 11:21:17] "GET /guest/admin HTTP/1.1" 200 -
